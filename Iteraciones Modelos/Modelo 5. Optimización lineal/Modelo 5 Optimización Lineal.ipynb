# %% [markdown]
# # Modelo 5. Optimización Lineal

# %% [markdown]
# ### Leer los datos

# %%
import pandas as pd

# ---------------
# IMPORTACIÓN DE DATOS
# ---------------
df_m = pd.read_excel('DT5.xlsx', sheet_name='Medicos')
df_s = pd.read_excel('DT5.xlsx', sheet_name='Pacientes')
df_e = pd.read_excel('DT5.xlsx', sheet_name='Clientes')

# ---------------
# CONJUNTOS
# ---------------
# # M = conjunto de médicos disponibles identificados por ID.
M = list(df_m['ID Medico'])
# S = conjunto de solicitudes identificadas por el ID del servicio.
S = list(df_s['ID Servicio'])
# E = conjunto de entidades.
E = list(df_e['Tipo'])

# ---------------
# PARÁMETROS
# ---------------
# Crear diccionario de parámetros
#------------ Parámetros asociados a los médicos
# i_m = documendo de identidad del médico m∈M.
i = dict(zip(M, df_m['Nombre Medico']))
# a_m = inicio de la jornada laboral del médico m∈M.
a = dict(zip(M, df_m['Inicio Jornada']))
# b_m = fin de la jornada laboral del médico m∈M.
b = dict(zip(M, df_m['Fin Jornada']))
# t_m = minuto en el que el médico m∈M está disponible.
t = dict(zip(M, df_m['Inicio Jornada']))
# c_m = número de solicitudes de servicio que se han  asignado al médico m∈M. 
c = dict(zip(M, [0]*len(M)))
lat = 4.681230925773865
lon = -74.06200456196707
# u_(i,j)^m = coordenadas i,j de la última ubicación geográfica del médico m∈M.
u = dict(zip(M, list(zip([lat]*len(M), [lon]*len(M)))))

#------------ Parámetros asociados a las solicitudes
# h_s = minuto en el que se recibió la solicitud s∈S.
h = dict(zip(S, df_s['Llegada']))
# d_s = duración de la atención de la solicitud s∈S.
d = dict(zip(S, df_s['Atencion']))
# e_s = entidad que solicitó el servicio s∈S.
e = dict(zip(S, df_s['Entidad']))
# v_(i,j)^s = coordenadas i,j de la ubicación geográfica de la solicitud s∈S.
v = dict(zip(S, list(zip(df_s['Latitud'], df_s['Longitud']))))

#------------ Parámetros asociados a las entidades
# f_e = tiempo en min. dentro del cual se debe atender las solicitudes de la entidad e∈E.
f = dict(zip(E, df_e['Tiempo']))

# %% [markdown]
# ### Calcular la distancia/tiempo entre cada par de nodos

# %%
from math import radians, cos, sin, asin, sqrt
def distancia_tierra(lat1, lat2, lon1, lon2):
    
    # Convertir grados a radianes.
    lon1 = radians(lon1)
    lon2 = radians(lon2)
    lat1 = radians(lat1)
    lat2 = radians(lat2)
      
    # Formula Haversine, para calcular la distancia entre dos puntos de una esfera dadas sus coordenadas de longitud y latitud
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * asin(sqrt(a))
    
    # Radio de la tierra en km.
    r = 6371
    
    respuesta = ((c * r)/24.9)*60
    # Calcular la distancia final en Km.
    return respuesta

# %% [markdown]
# ### Cambiar datos para Gantt

# %%
import datetime

def convertMin(minutos):
    # Obtenemos la fecha de hoy
    fecha_actual = datetime.date.today()
    # Combinamos la fecha de hoy con la hora 0:00:00
    fecha_hora = datetime.datetime.combine(fecha_actual, datetime.time.min) + datetime.timedelta(minutes=minutos)
    # Convertimos la fecha y hora a formato de cadena
    fecha_hora_str = fecha_hora.strftime("%Y-%m-%d %H:%M:%S")
    return fecha_hora_str

# %% [markdown]
# ### Asignación de los médicos

# %%
import pulp as lp

gantt = []
for s in S:

    # Tiempo máximo en el que se puede atender la solicitud s de acuerdo al tiempo contratado de la entidad.
    t_max = h[s] + f[e[s]]

    # Diccionario de distancias.
    dist = {(m, s): 0 for m in M}
    # Calcular las distancias entre los médicos y la solicitud y guardarlas en el diccionario.
    for m in M:
        distancia = distancia_tierra(v[s][0], u[m][0], v[s][1], u[m][1])
        dist[(m, s)] = distancia

    # Diccionario de pesos para balancaer la carga laboral
    p = {m: None for m in M}

    for m in M:

        if c[m] <= 2:
            p[m] = c[m] * 0.45 + (t[m] + dist[(m,s)]) * 0.55
        elif c[m] <= 4:
            p[m] = c[m] * 0.35 + (t[m] + dist[(m,s)]) * 0.65
        else:
            p[m] = c[m] * 0.25 + (t[m] + dist[(m,s)]) * 0.75

    # ---------------
    # MODELO DE OPTIMIZACIÓN
    # ---------------
    # Crear problema de optimización.
    prob = lp.LpProblem('Agendamiento_de_medicos_ADOM', lp.LpMinimize)

    # Crear variable de decisión.
    x = lp.LpVariable.dicts('x', [(s,m) for m in M], 0, 1, lp.LpBinary)

    # FUNCIÓN OBJETIVO
    prob += lp.lpSum(p[m]*x[(s,m)] for m in M)

    # RESTRICCIONES

    # 1. No se debe exceder el tiempo contratado por las entidades.    
    for m in M:
        if (t[m] + dist[(m, s)]) > t_max:
            prob += x[(s,m)] == 0

    # 2. No se puede asignar una solicitud a un médico por fuera de su jornada laboral.
    for m in M:
        if (t[m] + dist[(m,s)]) > b[m]:
            prob += x[(s,m)] == 0

    # 3. Restringir que cada solicitud sea asignada a un único médico.
    prob += lp.lpSum(x[(s,m)] for m in M) == 1

    # Optimizar el problema.
    prob.solve()

    # ---------------
    # ACTUALIZAR PARÁMETROS
    # ---------------
    print('Solicitud: ', s)
    contador = 0
    for m in M:
        if x[(s,m)].value() == 1:
            print('Se asignó médico: ', m)
            
            c[m] = c[m] + 1
            if h[s] < t[m]:
                gantt.append({'Solicitud': s , 'Médico': m, 'Inicio': convertMin(t[m] + dist[(m, s)]), 'Fin': convertMin(t[m] + dist[(m, s)] + d[s]), 'Distancia': dist[(m, s)], 'Inicio Jornada': a[m], 'Fin Jornada': b[m], 'Inicio traslado': t[m], 'Fin traslado': t[m] + dist[(m, s)], 'Inicio atención': t[m] + dist[(m, s)], 'Fin atención': t[m] + dist[(m, s)] + d[s], 'Llegada solicitud': h[s]})
                t[m] = t[m] + dist[(m,s)] + d[s]
            else:
                gantt.append({'Solicitud': s , 'Médico': m, 'Inicio': convertMin(h[s] + dist[(m, s)]), 'Fin': convertMin(h[s] + dist[(m, s)] + d[s]), 'Distancia': dist[(m, s)], 'Inicio Jornada': a[m], 'Fin Jornada': b[m], 'Inicio traslado': t[m], 'Fin traslado': h[s] + dist[(m, s)], 'Inicio atención': h[s] + dist[(m, s)], 'Fin atención': h[s] + dist[(m, s)] + d[s], 'Llegada solicitud': h[s]})
                t[m] = h[s] + dist[(m,s)] + d[s]

            print('Tiempo del médico: ', t[m])
            u[m] = (v[s][0], v[s][1])
            
        else:
            contador = contador + 1

    if contador == len(M):
        print('Minutos de la solicitud: ', h[s])
        print('Se cancela la solicitud: ', s)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/4d56e3e500204459b7319eaa4916c734-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/4d56e3e500204459b7319eaa4916c734-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 43 COLUMNS
# At line 237 RHS
# At line 276 BOUNDS
# At line 316 ENDATA
# Problem MODEL has 38 rows, 39 columns and 76 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2.81521 - 0.00 seconds
# Cgl0002I 37 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 2.81521 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.81521167
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
#
# Solicitud:  324231
# Se asignó médico:  1015405667
# Tiempo del médico:  20.118566674302407
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/4923f22003f040ab8fa3008b1c8e76a2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/4923f22003f040ab8fa3008b1c8e76a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 43 COLUMNS
# At line 237 RHS
# At line 276 BOUNDS
# At line 316 ENDATA
# Problem MODEL has 38 rows, 39 columns and 76 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12.7409 - 0.00 seconds
# Cgl0002I 37 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 12.7409 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.74091285
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324232
# Se asignó médico:  1032491705
# Tiempo del médico:  83.16529609831545
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/5d45a4484b9b44a6aa102a12df214d99-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/5d45a4484b9b44a6aa102a12df214d99-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 43 COLUMNS
# At line 237 RHS
# At line 276 BOUNDS
# At line 316 ENDATA
# Problem MODEL has 38 rows, 39 columns and 76 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 27.4751 - 0.00 seconds
# Cgl0002I 37 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 27.4751 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                27.47507949
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324233
# Se asignó médico:  1015405667
# Tiempo del médico:  116.01794149609469
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/283e97dcab614b49bdf593e8adca1cef-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/283e97dcab614b49bdf593e8adca1cef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 43 COLUMNS
# At line 237 RHS
# At line 276 BOUNDS
# At line 316 ENDATA
# Problem MODEL has 38 rows, 39 columns and 76 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 50.6169 - 0.00 seconds
# Cgl0002I 37 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 50.6169 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                50.61687571
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324236
# Se asignó médico:  1032491705
# Tiempo del médico:  162.04720519998958
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/efb10cef67da4f78b941fa2f4deea8a2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/efb10cef67da4f78b941fa2f4deea8a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 39 COLUMNS
# At line 229 RHS
# At line 264 BOUNDS
# At line 304 ENDATA
# Problem MODEL has 34 rows, 39 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 78.9704 - 0.00 seconds
# Cgl0002I 33 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 78.9704 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                78.97044626
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324240
# Se asignó médico:  1015405667
# Tiempo del médico:  246.92832443595813
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/fc68dec909db430a993ec8100aa1e496-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/fc68dec909db430a993ec8100aa1e496-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 39 COLUMNS
# At line 229 RHS
# At line 264 BOUNDS
# At line 304 ENDATA
# Problem MODEL has 34 rows, 39 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 96.0563 - 0.00 seconds
# Cgl0002I 33 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 96.0563 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                96.05630440
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324243
# Se asignó médico:  1032491705
# Tiempo del médico:  229.96425735187808
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/95e90b6bdd334b7d8549ca20e5c5cecd-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/95e90b6bdd334b7d8549ca20e5c5cecd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 223 RHS
# At line 255 BOUNDS
# At line 295 ENDATA
# Problem MODEL has 31 rows, 39 columns and 69 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 161.303 - 0.00 seconds
# Cgl0002I 30 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 161.303 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                161.30321606
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324244
# Se asignó médico:  1032491705
# Tiempo del médico:  277.5434093224184
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/3c46573295d7407e881553a8b2c4fd05-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/3c46573295d7407e881553a8b2c4fd05-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 223 RHS
# At line 255 BOUNDS
# At line 295 ENDATA
# Problem MODEL has 31 rows, 39 columns and 69 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 175.077 - 0.00 seconds
# Cgl0002I 30 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 175.077 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                175.07690786
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324246
# Se asignó médico:  80073352
# Tiempo del médico:  357.3216506540048
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/a752eaee45d04f0c9cff7d5c639168dc-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/a752eaee45d04f0c9cff7d5c639168dc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 37 COLUMNS
# At line 225 RHS
# At line 258 BOUNDS
# At line 298 ENDATA
# Problem MODEL has 32 rows, 39 columns and 70 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 179.795 - 0.00 seconds
# Cgl0002I 31 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 179.795 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                179.79493061
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324248
# Se asignó médico:  1015405667
# Tiempo del médico:  297.99220093488907
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/99e8ada374394a1ba3891cbca5894eaa-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/99e8ada374394a1ba3891cbca5894eaa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 34 COLUMNS
# At line 219 RHS
# At line 249 BOUNDS
# At line 289 ENDATA
# Problem MODEL has 29 rows, 39 columns and 67 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 173.845 - 0.00 seconds
# Cgl0002I 28 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 173.845 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                173.84455830
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324255
# Se asignó médico:  52997773
# Tiempo del médico:  346.08101509963313
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/0840d8b2132845b990af89c3df1c6407-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/0840d8b2132845b990af89c3df1c6407-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 34 COLUMNS
# At line 219 RHS
# At line 249 BOUNDS
# At line 289 ENDATA
# Problem MODEL has 29 rows, 39 columns and 67 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 178.072 - 0.00 seconds
# Cgl0002I 28 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 178.072 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                178.07165825
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324257
# Se asignó médico:  1015437933
# Tiempo del médico:  332.766651362099
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/937650cf1a7c4eb5acc40feff1b40690-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/937650cf1a7c4eb5acc40feff1b40690-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 34 COLUMNS
# At line 219 RHS
# At line 249 BOUNDS
# At line 289 ENDATA
# Problem MODEL has 29 rows, 39 columns and 67 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 176.992 - 0.00 seconds
# Cgl0002I 28 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 176.992 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                176.99151742
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324259
# Se asignó médico:  1018472151
# Tiempo del médico:  335.8027589410136
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/4cb49f5117714c5bb68b99887e3a5be6-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/4cb49f5117714c5bb68b99887e3a5be6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 34 COLUMNS
# At line 219 RHS
# At line 249 BOUNDS
# At line 289 ENDATA
# Problem MODEL has 29 rows, 39 columns and 67 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 189.382 - 0.00 seconds
# Cgl0002I 28 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 189.382 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                189.38192290
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324260
# Se asignó médico:  1018472151
# Tiempo del médico:  358.5125870890488
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/6a0f98c2fe9f400cafc868e6312bbed1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/6a0f98c2fe9f400cafc868e6312bbed1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 34 COLUMNS
# At line 219 RHS
# At line 249 BOUNDS
# At line 289 ENDATA
# Problem MODEL has 29 rows, 39 columns and 67 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 189.843 - 0.00 seconds
# Cgl0002I 28 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 189.843 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                189.84266730
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324261
# Se asignó médico:  1015437933
# Tiempo del médico:  359.3503041900061
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/e37f27ddd6f94c3abe696ace589f1cc5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/e37f27ddd6f94c3abe696ace589f1cc5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 211 RHS
# At line 237 BOUNDS
# At line 277 ENDATA
# Problem MODEL has 25 rows, 39 columns and 63 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 184.715 - 0.00 seconds
# Cgl0002I 24 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 184.715 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                184.71517155
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324265
# Se asignó médico:  1032491705
# Tiempo del médico:  345.4799315290682
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/fef7cd52c61e48e9806c20c8ec7f52e1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/fef7cd52c61e48e9806c20c8ec7f52e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 213 RHS
# At line 240 BOUNDS
# At line 280 ENDATA
# Problem MODEL has 26 rows, 39 columns and 64 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 198.957 - 0.00 seconds
# Cgl0002I 25 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 198.957 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                198.95704895
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324268
# Se asignó médico:  80073352
# Tiempo del médico:  372.9219071754263
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/946a0b31fff045ba99c5bba519c5cd6f-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/946a0b31fff045ba99c5bba519c5cd6f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 213 RHS
# At line 240 BOUNDS
# At line 280 ENDATA
# Problem MODEL has 26 rows, 39 columns and 64 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 204.153 - 0.00 seconds
# Cgl0002I 25 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 204.153 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                204.15297106
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324269
# Se asignó médico:  1015437933
# Tiempo del médico:  401.5508564812577
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/942301b994914fc69c678a38a211dc7b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/942301b994914fc69c678a38a211dc7b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 213 RHS
# At line 240 BOUNDS
# At line 280 ENDATA
# Problem MODEL has 26 rows, 39 columns and 64 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 207.486 - 0.00 seconds
# Cgl0002I 25 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 207.486 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                207.48643868
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324270
# Se asignó médico:  1018472151
# Tiempo del médico:  392.61170669126955
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/87648b1ce7ff4783b08a27a7984b98d7-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/87648b1ce7ff4783b08a27a7984b98d7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 213 RHS
# At line 240 BOUNDS
# At line 280 ENDATA
# Problem MODEL has 26 rows, 39 columns and 64 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 195.584 - 0.00 seconds
# Cgl0002I 25 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 195.584 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                195.58417589
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324271
# Se asignó médico:  52997773
# Tiempo del médico:  393.7083956022521
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/88693770b23d46c8a93f9cf40bcb22e5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/88693770b23d46c8a93f9cf40bcb22e5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 213 RHS
# At line 240 BOUNDS
# At line 280 ENDATA
# Problem MODEL has 26 rows, 39 columns and 64 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 208.81 - 0.00 seconds
# Cgl0002I 25 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 208.81 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                208.81020058
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324272
# Se asignó médico:  79955886
# Tiempo del médico:  395.6549101520466
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/cd9db67a8bd4481c9537c05d0b349335-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/cd9db67a8bd4481c9537c05d0b349335-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 31 COLUMNS
# At line 213 RHS
# At line 240 BOUNDS
# At line 280 ENDATA
# Problem MODEL has 26 rows, 39 columns and 64 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 204.14 - 0.00 seconds
# Cgl0002I 25 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 204.14 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 215 RHS
# At line 243 BOUNDS
# At line 283 ENDATA
# Problem MODEL has 27 rows, 39 columns and 65 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 916.113 - 0.00 seconds
# Cgl0002I 26 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 916.113 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                916.11273206
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Solicitud:  324612
# Se asignó médico:  1083012532
# Tiempo del médico:  1265.5006158955553
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/be747b56bfbb47159335a04e30c1f954-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/be747b56bfbb47159335a04e30c1f954-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 215 RHS
# At line 243 BOUNDS
# At line 283 ENDATA
# Problem MODEL has 27 rows, 39 columns and 65 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 919.794 - 0.00 seconds
# Cgl0002I 26 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 919.794 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                919.79422396
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324613
# Se asignó médico:  1018440480
# Tiempo del médico:  1273.7423139080884
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/25326e0d6c1d4e39828e598d7193f9f6-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/25326e0d6c1d4e39828e598d7193f9f6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 215 RHS
# At line 243 BOUNDS
# At line 283 ENDATA
# Problem MODEL has 27 rows, 39 columns and 65 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 933.085 - 0.00 seconds
# Cgl0002I 26 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 933.085 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                933.08505168
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324614
# Se asignó médico:  1019074166
# Tiempo del médico:  1299.446735571719
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/ebf46c12348e4860959f3ec0ec110a88-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/ebf46c12348e4860959f3ec0ec110a88-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 215 RHS
# At line 243 BOUNDS
# At line 283 ENDATA
# Problem MODEL has 27 rows, 39 columns and 65 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 931.031 - 0.00 seconds
# Cgl0002I 26 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 931.031 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                931.03127141
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324615
# Se asignó médico:  1014217039
# Tiempo del médico:  1274.8624861037
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/ac6ad046050940739203e493307e7fc2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/ac6ad046050940739203e493307e7fc2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 33 COLUMNS
# At line 217 RHS
# At line 246 BOUNDS
# At line 286 ENDATA
# Problem MODEL has 28 rows, 39 columns and 66 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 937.706 - 0.00 seconds
# Cgl0002I 27 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 937.706 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                937.70598452
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324616
# Se asignó médico:  80075437
# Tiempo del médico:  1306.9706563443676
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/c7483441fcd340f78dbf3b834f2b1a73-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/c7483441fcd340f78dbf3b834f2b1a73-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 32 COLUMNS
# At line 215 RHS
# At line 243 BOUNDS
# At line 283 ENDATA
# Problem MODEL has 27 rows, 39 columns and 65 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 935.535 - 0.00 seconds
# Cgl0002I 26 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 935.535 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                935.53529620
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324619
# Se asignó médico:  85488148
# Tiempo del médico:  1333.4975983454985
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/marianamb/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/225f98a78ae941a79c0d9e7425f4607e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/7f/dyxrc8wx4rn5y924zhd8473m0000gn/T/225f98a78ae941a79c0d9e7425f4607e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 33 COLUMNS
# At line 217 RHS
# At line 246 BOUNDS
# At line 286 ENDATA
# Problem MODEL has 28 rows, 39 columns and 66 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 955.148 - 0.00 seconds
# Cgl0002I 27 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 955.148 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                955.14805833
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solicitud:  324620
# Se asignó médico:  1014266018
# Tiempo del médico:  1370.7810030647258

# %% [markdown]
# ### Gantt general

# %%
import plotly.express as px
import pandas as pd
#Poner los datos de la lista en un dataframe
df1 = pd.DataFrame(gantt)
# poner los datos en el formato que requiere plotly poner la columna solicitud como texto
df1['Solicitud'] = df1['Solicitud'].astype(str)
# poner la columna médico como texto
df1['Médico'] = df1['Médico'].astype(str)

fig = px.timeline(df1, x_start="Inicio", x_end="Fin", y="Médico", color="Médico",
                  hover_name="Solicitud",
                  title="Solicitudes atendidas por médicos")
fig.update_layout(xaxis_title="Tiempo", yaxis_title="Médico")
fig.update_yaxes(autorange="reversed")
fig.update_xaxes(rangeslider_visible=True)
# Hacer el grafico más grande para que se vea mejor
fig.update_layout(
    autosize=False,
    width=1000,
    height=500,
)
fig.show()
